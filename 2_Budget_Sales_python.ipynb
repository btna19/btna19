# %% [markdown]
# <a href="https://colab.research.google.com/github/btna19/btna19/blob/main/2_Budget_Sales_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.style.use("seaborn-v0_8-whitegrid")
import warnings
warnings.filterwarnings('ignore')

# %%
calender=pd.read_csv("/content/calender.csv")
customers=pd.read_csv("/content/customers.csv", encoding='latin-1')
product=pd.read_csv("/content/product.csv")
territory=pd.read_csv("/content/territory.csv")
sales=pd.read_csv("/content/sales.csv")

# %% [markdown]
# CALENDAR DATASET

# %%
calender.head()
# Out:
#                Date   DateKey  Year Quarter  MonthNum Month FiscalYear  \
# 0  03-04-2016 00:00  20160403  2016      Q2         4   Apr     FY2016
# 1  04-04-2016 00:00  20160404  2016      Q2         4   Apr     FY2016
# 2  05-04-2016 00:00  20160405  2016      Q2         4   Apr     FY2016
# 3  06-04-2016 00:00  20160406  2016      Q2         4   Apr     FY2016
# 4  07-04-2016 00:00  20160407  2016      Q2         4   Apr     FY2016
#
#   FiscalQuarter  FiscalMonthNum FiscalMonth MonthYear MonthYearLong  \
# 0           FQ4              10         Apr    Apr-16      Apr-2016
# 1           FQ4              10         Apr    Apr-16      Apr-2016
# 2           FQ4              10         Apr    Apr-16      Apr-2016
# 3           FQ4              10         Apr    Apr-16      Apr-2016
# 4           FQ4              10         Apr    Apr-16      Apr-2016
#
#    MonthYearNum  WeekdayNum Weekday WeekdayWeekend
# 0        201604           1     Sun        Weekend
# ...

# %%
calender.columns.to_list()
# Out:
# ['Date',
#  'DateKey',
#  'Year',
#  'Quarter',
#  'MonthNum',
#  'Month',
#  'FiscalYear',
#  'FiscalQuarter',
#  'FiscalMonthNum',
#  'FiscalMonth',
#  'MonthYear',
#  'MonthYearLong',
#  'MonthYearNum',
#  'WeekdayNum',
#  'Weekday',
#  'WeekdayWeekend']

# %%
calender.shape
# Out:
# (1461, 16)

# %% [markdown]
# CUSTOMER DATASET

# %%
customers.head()
# Out:
#    CustomerKey  FirstName LastName            FullName         BirthDate  \
# 0        11000        Jon     Yang           Yang, Jon  08-04-1966 00:00
# 1        11001     Eugene    Huang       Huang, Eugene  14-05-1965 00:00
# 2        11002      Ruben   Torres       Torres, Ruben  12-08-1965 00:00
# 3        11003    Christy      Zhu        Zhu, Christy  15-02-1968 00:00
# 4        11004  Elizabeth  Johnson  Johnson, Elizabeth  08-08-1968 00:00
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M         90000              2                     0
# 1             S      M         60000              3                     3
# 2             M      M         60000              3                     3
# 3             S      F         70000              0                     0
# 4             S      F         80000              5                     5
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned  \
# ...

# %%
customers.columns.to_list()
# Out:
# ['CustomerKey',
#  'FirstName',
#  'LastName',
#  'FullName',
#  'BirthDate',
#  'MaritalStatus',
#  'Gender',
#  'YearlyIncome',
#  'TotalChildren',
#  'NumberChildrenAtHome',
#  'Education',
#  'Occupation',
#  'HouseOwnerFlag',
#  'NumberCarsOwned',
#  'AddressLine1',
#  'DateFirstPurchase',
#  'CommuteDistance']

# %%
customers = customers[['CustomerKey','Gender','BirthDate','MaritalStatus','YearlyIncome']].copy()

# %%
customers.shape
# Out:
# (18484, 5)

# %%
customers.isnull().sum()
# Out:
# CustomerKey      0
# Gender           0
# BirthDate        0
# MaritalStatus    0
# YearlyIncome     0
# dtype: int64

# %% [markdown]
# PRODUCT DATASET

# %%
product.head()
# Out:
#    ProductKey            ProductName SubCategory Category  StandardCost Color  \
# 0           1        Adjustable Race         NaN      NaN           NaN   NaN
# 1           2           Bearing Ball         NaN      NaN           NaN   NaN
# 2           3        BB Ball Bearing         NaN      NaN           NaN   NaN
# 3           4  Headset Ball Bearings         NaN      NaN           NaN   NaN
# 4           5                  Blade         NaN      NaN           NaN   NaN
#
#    ListPrice  DaysToManufacture ProductLine ModelName  \
# 0        NaN                  0         NaN       NaN
# 1        NaN                  0         NaN       NaN
# 2        NaN                  1         NaN       NaN
# 3        NaN                  0         NaN       NaN
# 4        NaN                  1         NaN       NaN
#
#                                                Photo ProductDescription  \
# 0  http://www.avising.com/me/LearnPBI/DataSources...                NaN
# ...

# %%
product.columns.to_list()
# Out:
# ['ProductKey',
#  'ProductName',
#  'SubCategory',
#  'Category',
#  'StandardCost',
#  'Color',
#  'ListPrice',
#  'DaysToManufacture',
#  'ProductLine',
#  'ModelName',
#  'Photo',
#  'ProductDescription',
#  'StartDate']

# %%
product = product[['ProductKey','ProductName','SubCategory','Category','ProductLine']].copy()

# %%
product.shape
# Out:
# (606, 5)

# %%
product.isnull().sum()
# Out:
# ProductKey       0
# ProductName      0
# SubCategory    209
# Category       209
# ProductLine    226
# dtype: int64

# %%
product.loc[product['SubCategory'].isnull()].head()
# Out:
#    ProductKey            ProductName SubCategory Category ProductLine
# 0           1        Adjustable Race         NaN      NaN         NaN
# 1           2           Bearing Ball         NaN      NaN         NaN
# 2           3        BB Ball Bearing         NaN      NaN         NaN
# 3           4  Headset Ball Bearings         NaN      NaN         NaN
# 4           5                  Blade         NaN      NaN         NaN

# %%
product = product.dropna()

# %%
product.isnull().sum()
# Out:
# ProductKey     0
# ProductName    0
# SubCategory    0
# Category       0
# ProductLine    0
# dtype: int64

# %% [markdown]
# TERRITORY DATASET

# %%
territory.head()
# Out:
#    SalesTerritoryKey     Region        Country          Group  \
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
# 2                  3    Central  United States  North America
# 3                  4  Southwest  United States  North America
# 4                  5  Southeast  United States  North America
#
#                                          RegionImage
# 0  http://www.avising.com/me/LearnPBI/DataSources...
# 1  http://www.avising.com/me/LearnPBI/DataSources...
# 2  http://www.avising.com/me/LearnPBI/DataSources...
# 3  http://www.avising.com/me/LearnPBI/DataSources...
# 4  http://www.avising.com/me/LearnPBI/DataSources...

# %%
territory.shape
# Out:
# (11, 5)

# %%
territory.columns.to_list()
# Out:
# ['SalesTerritoryKey', 'Region', 'Country', 'Group', 'RegionImage']

# %%
territory = territory[['SalesTerritoryKey', 'Region', 'Country', 'Group']].copy()

# %%
territory.isnull().sum()
# Out:
# SalesTerritoryKey    0
# Region               1
# Country              1
# Group                1
# dtype: int64

# %%
territory
# Out:
#     SalesTerritoryKey          Region         Country          Group
# 0                   1       Northwest   United States  North America
# 1                   2       Northeast   United States  North America
# 2                   3         Central   United States  North America
# 3                   4       Southwest   United States  North America
# 4                   5       Southeast   United States  North America
# 5                   6          Canada          Canada  North America
# 6                   7          France          France         Europe
# 7                   8         Germany         Germany         Europe
# 8                   9       Australia       Australia        Pacific
# 9                  10  United Kingdom  United Kingdom         Europe
# 10                 11             NaN             NaN            NaN

# %% [markdown]
# SALES DATASET

# %%
sales.shape
# Out:
# (40852, 25)

# %%
sales.columns.tolist()
# Out:
# ['ProductKey',
#  'OrderDate',
#  'ShipDate',
#  'CustomerKey',
#  'PromotionKey',
#  'SalesTerritoryKey',
#  'SalesOrderNumber',
#  'SalesOrderLineNumber',
#  'OrderQuantity',
#  'UnitPrice',
#  'TotalProductCost',
#  'SalesAmount',
#  'TaxAmt',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'StandardCost',
#  'List Price',
#  'Unnamed: 22',
#  'diif std cost',
#  'diff list price']

# %%
sales = sales[['ProductKey',
 'OrderDate',
 'ShipDate',
 'CustomerKey',
 'SalesTerritoryKey',
 'SalesOrderNumber',
 'SalesOrderLineNumber',
 'OrderQuantity',
 'UnitPrice',
 'TotalProductCost',
 'SalesAmount',
 'TaxAmt']]

# %%
sales = sales.rename(columns={'TaxAmt':"TaxAmount",'Total sales revenue':"TotalSalesRevenue",'Gross Profit':"GrossProfit"})

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40852 entries, 0 to 40851
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductKey            40852 non-null  int64
#  1   OrderDate             40852 non-null  object
#  2   ShipDate              40851 non-null  object
#  3   CustomerKey           40851 non-null  float64
#  4   SalesTerritoryKey     40851 non-null  float64
#  5   SalesOrderNumber      40851 non-null  object
#  6   SalesOrderLineNumber  40851 non-null  float64
#  7   OrderQuantity         40851 non-null  float64
#  8   UnitPrice             40851 non-null  float64
#  9   TotalProductCost      40851 non-null  float64
#  10  SalesAmount           40851 non-null  float64
#  11  TaxAmount             40851 non-null  float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 3.7+ MB

# %%
sales['OrderDate'] = pd.to_datetime(sales['OrderDate'], errors='coerce')

# %%
sales['ShipDate'] = pd.to_datetime(sales['ShipDate'],format='mixed')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40852 entries, 0 to 40851
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductKey            40852 non-null  int64
#  1   OrderDate             16546 non-null  datetime64[ns]
#  2   ShipDate              40851 non-null  datetime64[ns]
#  3   CustomerKey           40851 non-null  float64
#  4   SalesTerritoryKey     40851 non-null  float64
#  5   SalesOrderNumber      40851 non-null  object
#  6   SalesOrderLineNumber  40851 non-null  float64
#  7   OrderQuantity         40851 non-null  float64
#  8   UnitPrice             40851 non-null  float64
#  9   TotalProductCost      40851 non-null  float64
#  10  SalesAmount           40851 non-null  float64
#  11  TaxAmount             40851 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(1), object(1)
# memory usage: 3.7+ MB

# %%
sales.isnull().sum()
# Out:
# ProductKey                  0
# OrderDate               24306
# ShipDate                    1
# CustomerKey                 1
# SalesTerritoryKey           1
# SalesOrderNumber            1
# SalesOrderLineNumber        1
# OrderQuantity               1
# UnitPrice                   1
# TotalProductCost            1
# SalesAmount                 1
# TaxAmount                   1
# dtype: int64

# %%
sales.dropna()
# Out:
#        ProductKey  OrderDate   ShipDate  CustomerKey  SalesTerritoryKey  \
# 0             310 2014-01-01 2014-08-01      21768.0                6.0
# 1             346 2014-01-01 2014-08-01      28389.0                7.0
# 2             346 2014-01-01 2014-08-01      25863.0                1.0
# 3             336 2014-01-01 2014-08-01      14501.0                4.0
# 4             346 2014-01-01 2014-08-01      11003.0                9.0
# ...           ...        ...        ...          ...                ...
# 39173         561 2016-12-09 2016-09-19      12341.0                9.0
# 39174         541 2016-12-09 2016-09-19      12341.0                9.0
# 39175         530 2016-12-09 2016-09-19      12341.0                9.0
# 39176         465 2016-12-09 2016-09-19      12341.0                9.0
# 39177         491 2016-12-09 2016-09-19      12341.0                9.0
#
#       SalesOrderNumber  SalesOrderLineNumber  OrderQuantity  UnitPrice  \
# ...

# %% [markdown]
# DOWNLOADING REVISED DATASETS

# %%
sales.to_csv("Revised_sales.csv")

# %%
customers.to_csv("Revised_customer.csv")

# %%
product.to_csv("Revised_product.csv")

# %%
territory.to_csv("Revised_territory.csv")

# %%
calender.to_csv("Revised_calender.csv")
